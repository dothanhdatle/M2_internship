# %%
# !pip install umap-learn

# %%
import numpy as np
import random
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch

from data.data_loader import Data_Loader
from models.CVAE import CVAE
from models.DVAE import DVAE
from models.MLVAE import MLVAE
from models.HVAE import HVAE
from models.pxz_distributions.Gauss import Gaussian
from training.preprocessor import Preprocessor
from training.trainer import Trainer
from utils.latent_space import latent_cvae, latent_dvae, latent_mlvae, dimension_reduce
from utils.baseline import baseline_prediction_data, mse_miss_recon
from utils.reconstruction_cvae import reconstruct_all_cvae
from utils.reconstruction_dvae import reconstruct_all_dvae
from utils.reconstruction_mlvae import reconstruct_all_mlvae
#from models.utils.plot import nirs_comparison_plot

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
# reproducibility
import random
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)

torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# # Raw spectral data

# %% [markdown]
# ## 1. Load data and preprocessing

# %%
# NIRS data
nirs_data = pd.read_csv('./data/Pois/NirsA.csv')
nirs_data = nirs_data.drop('Supplement', axis = 1) # remove the column 'Supplement'
nirs_data.head()
# Out:
#     GenoID Environnement     400,0     400,5     401,0     401,5     402,0  \
# 0  Geno173     MONS_2023  0.754366  0.755454  0.756477  0.757439  0.758345
# 1  Geno112     MONS_2023  0.737204  0.738158  0.739049  0.739882  0.740661
# 2  Geno126     MONS_2023  0.762879  0.764205  0.765458  0.766642  0.767763
# 3  Geno116     MONS_2023  0.722704  0.723704  0.724646  0.725534  0.726373
# 4  Geno216     MONS_2023  0.744163  0.745224  0.746223  0.747164  0.748052
#
#       402,5     403,0     403,5  ...    2495,0    2495,5    2496,0    2496,5  \
# 0  0.759200  0.760008  0.760771  ...  1.468137  1.468241  1.468323  1.468384
# 1  0.741390  0.742072  0.742708  ...  1.452030  1.452174  1.452276  1.452335
# 2  0.768824  0.769831  0.770783  ...  1.425344  1.425385  1.425388  1.425354
# 3  0.727166  0.727917  0.728628  ...  1.473338  1.473504  1.473627  1.473704
# 4  0.748891  0.749684  0.750432  ...  1.459398  1.459463  1.459498  1.459500
#
#      2497,0    2497,5    2498,0    2498,5    2499,0    2499,5
# 0  1.468423  1.468440  1.468432  1.468393  1.468321  1.468206
# 1  1.452351  1.452325  1.452260  1.452157  1.452022  1.451852
# 2  1.425290  1.425198  1.425083  1.424945  1.424786  1.424601
# 3  1.473738  1.473730  1.473681  1.473590  1.473460  1.473285
# 4  1.459470  1.459407  1.459313  1.459189  1.459039  1.458860
#
# [5 rows x 4202 columns]

# %%
len(nirs_data)
# Out:
# 2545

# %%
# Preprocessing data
Preprocessor = Preprocessor()
preprocessed_data = Preprocessor.preprocess(nirs_data)
data_load= Data_Loader(test_size=0.2,remove_percentage=0.6, batch_size=32, num_vars=10, random_state=42)

# %%
# Split and create missing data
np.random.seed(seed)
random.seed(seed)
train_gt, test_gt = data_load.data_split(preprocessed_data)
train_miss_60, test_miss_60 = data_load.create_missing(train_gt, test_gt)

# %%
# Environnement missing checking
environment_counts = train_miss_60.groupby('GenoID')['Environnement'].nunique().reset_index()
environment_counts.columns = ['GenoID', 'EnvironmentCount']
environment_counts[environment_counts.EnvironmentCount < 8].sort_values(by='EnvironmentCount',ascending=False)
# Out:
#       GenoID  EnvironmentCount
# 145  Geno268                 7
# 213   Geno85                 6
# 57   Geno162                 6
# 164    Geno3                 6
# 21   Geno122                 6
# ..       ...               ...
# 96   Geno209                 1
# 95   Geno208                 1
# 33   Geno135                 1
# 51   Geno157                 1
# 75   Geno184                 1
#
# [228 rows x 2 columns]

# %%
# Baseline predition performance
miss_baseline_train = baseline_prediction_data(train_miss_60)
miss_baseline_test = baseline_prediction_data(test_miss_60)
mse_base_train, mse_base_train_df = mse_miss_recon(miss_baseline_train, train_gt)
print(f'MSE for baseline prediction of training set: {mse_base_train}')

mse_base_test, mse_base_test_df = mse_miss_recon(miss_baseline_test, test_gt)
print(f'Average MSE for baseline prediction of validation set: {mse_base_test}')
# Out:
# No NIRS groundtruth available for the Geno76 in the environment Ragt_2022
# No NIRS groundtruth available for the Geno84 in the environment Ragt_2021
# MSE for baseline prediction of training set: 0.0006063429044374437
# No NIRS groundtruth available for the Geno187 in the environment Ragt_2022
# No NIRS groundtruth available for the Geno265 in the environment Ragt_2022
# Average MSE for baseline prediction of validation set: 0.0010065292140328235

# %%
# one-hot total size in CVAE
cond_dim = train_miss_60.GenoID.unique().shape[0] + train_miss_60.Environnement.unique().shape[0]
cond_dim
# Out:
# 237

# %%
# Define models
cvae = CVAE(Gaussian, input_dim = 4200, cond_dim = cond_dim, hidden_dims=[512, 256],latent_dim=128,
            beta = 1, beta_annealing=False)
cvae.to(device)

dvae = DVAE(Gaussian, input_dim = 4200, hidden_dims=[512, 256], latent_dim=16, vari_latent_size=14,
            beta = 0.1, beta_annealing=False)
dvae.to(device)

mlvae = MLVAE(Gaussian, input_dim = 4200, hidden_dims=[512, 256],latent_dim=128, vari_latent_size=100,
              beta_v = 0.1, beta_e = 0.1, beta_annealing=False)
mlvae.to(device)

hvae = HVAE(Gaussian, input_dim = 4200, hidden_dims=[512, 256],latent_dim=128, vari_latent_size=100,
            var_v_init = 0.1, var_e_init = 0.1,
            beta_v = 1, beta_e = 1, beta_ve = 1, beta_ev = 1, beta_annealing=False)
hvae.to(device)
# Out:
# HVAE(
#   (pxz_distribution): Gaussian()
#   (enc_mlp): Sequential(
#     (0): Sequential(
#       (0): LinearNorm(
#         (linear_layer): Linear(in_features=4200, out_features=512, bias=True)
#       )
#       (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (2): SiLU()
#     )
#     (1): Sequential(
#       (0): LinearNorm(
#         (linear_layer): Linear(in_features=512, out_features=256, bias=True)
#       )
#       (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (2): SiLU()
#     )
#   )
#   (enc_linear): LinearNorm(
#     (linear_layer): Linear(in_features=256, out_features=256, bias=True)
#   )
#   (ve_mlp): LinearNorm(
#     (linear_layer): Linear(in_features=256, out_features=200, bias=True)
#   )
#   (ev_mlp): LinearNorm(
#     (linear_layer): Linear(in_features=256, out_features=56, bias=True)
#   )
#   (dec_mlp): Sequential(
#     (0): Sequential(
#       (0): LinearNorm(
#         (linear_layer): Linear(in_features=128, out_features=256, bias=True)
#       )
#       (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (2): SiLU()
#     )
#     (1): Sequential(
#       (0): LinearNorm(
#         (linear_layer): Linear(in_features=256, out_features=512, bias=True)
#       )
#       (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (2): SiLU()
#     )
#   )
#   (dec_linear): LinearNorm(
#     (linear_layer): Linear(in_features=512, out_features=8400, bias=True)
#   )
# )

# %%
# define optimizer
lr_cvae = 1e-3
optimizer_cvae = torch.optim.Adam(cvae.parameters(), lr=lr_cvae)

lr_dvae = 1e-4
optimizer_dvae = torch.optim.Adam(dvae.parameters(), lr=lr_dvae)

lr_mlvae = 1e-4
optimizer_mlvae = torch.optim.Adam(mlvae.parameters(), lr=lr_mlvae)

lr_hvae = 1e-2
optimizer_hvae = torch.optim.Adam(hvae.parameters(), lr=lr_hvae)

# %%
# define trainer class
cvae_trainer = Trainer(model_type='cvae', model=cvae, data=nirs_data, data_loader = data_load, optimizer=optimizer_cvae)
dvae_trainer = Trainer(model_type='dvae', model=dvae, data=nirs_data, data_loader = data_load, optimizer=optimizer_dvae)
mlvae_trainer = Trainer(model_type='mlvae', model=mlvae, data=nirs_data, data_loader = data_load, optimizer=optimizer_mlvae)
hvae_trainer = Trainer(model_type='hvae', model=hvae, data=nirs_data, data_loader = data_load, optimizer=optimizer_hvae)

# %%
# Training CVAE
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)
torch.cuda.manual_seed(seed)
train_loss, train_loss_dict, train_mse, best_epoch = cvae_trainer.train(nb_epochs=500,device=device,print_rate=100,model_save_path='saved_models/cvae_raw_60.pth')
# Out:
# Epoch [1/500]:
# Reconstruction:
# Train: ELBO: -0.0299, Reconstruction term 1: 0.0290, KLD term: 0.0589.
# Predict missing NIRS:
# Train set: MSE: 0.0059923
# min MSE: 0.005992319887916317.
# Epoch [100/500]:
# Reconstruction:
# Train: ELBO: 2.6364, Reconstruction term 1: 2.6380, KLD term: 0.0016.
# Predict missing NIRS:
# Train set: MSE: 0.0010103
# min MSE: 0.0007494799181656062.
# Epoch [200/500]:
# Reconstruction:
# Train: ELBO: 1.5514, Reconstruction term 1: 1.5518, KLD term: 0.0004.
# Predict missing NIRS:
# Train set: MSE: 0.0013885
# min MSE: 0.0007494799181656062.
# Epoch [300/500]:
# Reconstruction:
# Train: ELBO: 2.7667, Reconstruction term 1: 2.7674, KLD term: 0.0007.
# Predict missing NIRS:
# Train set: MSE: 0.0010859
# min MSE: 0.0006137293464933548.
# Epoch [400/500]:
# Reconstruction:
# Train: ELBO: 2.0421, Reconstruction term 1: 2.0427, KLD term: 0.0006.
# Predict missing NIRS:
# Train set: MSE: 0.0015821
# min MSE: 0.0005857337573174899.
# Epoch [500/500]:
# Reconstruction:
# Train: ELBO: 3.5999, Reconstruction term 1: 3.6003, KLD term: 0.0004.
# Predict missing NIRS:
# Train set: MSE: 0.0007130
# min MSE: 0.0005857337573174899.

# %%
# PLot training ELBO curve and MSE loss in prediction missing NIRS
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(18,8))
ax1.plot(train_loss, label='Training set', marker='o', linestyle='solid', linewidth=1, markersize=3)
#ax1.plot(valid_loss, label='Validation set', marker='o', linestyle='solid', linewidth=1, markersize=3)
ax1.axvline(x = best_epoch, color='r', linestyle = '--')
ax1.set_title('ELBO for CVAE')
ax1.legend(loc='lower right')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('ELBO')

ax2.plot(train_mse, marker='o', linestyle='solid',linewidth=1, markersize=3)
#ax2.plot(valid_mse, label='Validation set', marker='o', linestyle='solid',linewidth=1, markersize=3)
ax2.axvline(x = best_epoch, color='r', linestyle = '--')
ax2.set_ylim(2e-4, 2e-3)
ax2.set_title("MSE for the missing NIRS reconstruction in training set of CVAE")
ax2.legend(loc='upper right')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('MSE')
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0, 0.5, 'MSE')

# %%
# Training DVAE
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)
torch.cuda.manual_seed(seed)
train_loss, train_loss_dict, train_mse, best_epoch = dvae_trainer.train(nb_epochs=500,device=device,print_rate=100,model_save_path='saved_models/dvae_raw_60.pth')
# Out:
# Epoch [1/500]:
# Reconstruction:
# Train: ELBO: -2.3387, Reconstruction term 1: -1.1482, Reconstruction term 2: -1.1477, KLD term 1: 0.2139, KLD term 2: 0.2140.
# Predict missing NIRS:
# Train set: MSE: 0.3716918
# min MSE: 0.3716917509010307.
# Epoch [100/500]:
# Reconstruction:
# Train: ELBO: 4.1571, Reconstruction term 1: 2.1023, Reconstruction term 2: 2.1020, KLD term 1: 0.2365, KLD term 2: 0.2365.
# Predict missing NIRS:
# Train set: MSE: 0.0014988
# min MSE: 0.0014458166092729706.
# Epoch [200/500]:
# Reconstruction:
# Train: ELBO: 4.1803, Reconstruction term 1: 2.1240, Reconstruction term 2: 2.0850, KLD term 1: 0.1437, KLD term 2: 0.1437.
# Predict missing NIRS:
# Train set: MSE: 0.0014757
# min MSE: 0.0014442191209658743.
# Epoch [300/500]:
# Reconstruction:
# Train: ELBO: 4.2101, Reconstruction term 1: 2.0817, Reconstruction term 2: 2.1508, KLD term 1: 0.1121, KLD term 2: 0.1121.
# Predict missing NIRS:
# Train set: MSE: 0.0014520
# min MSE: 0.0014434095030917166.
# Epoch [400/500]:
# Reconstruction:
# Train: ELBO: 4.4957, Reconstruction term 1: 2.3056, Reconstruction term 2: 2.2541, KLD term 1: 0.3234, KLD term 2: 0.3164.
# Predict missing NIRS:
# Train set: MSE: 0.0009736
# min MSE: 0.0009315803115457295.
# Epoch [500/500]:
# Reconstruction:
# Train: ELBO: 5.2311, Reconstruction term 1: 2.6817, Reconstruction term 2: 2.6670, KLD term 1: 0.5877, KLD term 2: 0.5883.
# Predict missing NIRS:
# Train set: MSE: 0.0006899
# min MSE: 0.00048329999690818683.

# %%
# PLot training ELBO curve and MSE loss in prediction missing NIRS
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(18,8))
ax1.plot(train_loss, label='Training set', marker='o', linestyle='solid', linewidth=1, markersize=3)
#ax1.plot(valid_loss, label='Validation set', marker='o', linestyle='solid', linewidth=1, markersize=3)
ax1.axvline(x = best_epoch, color='r', linestyle = '--')
ax1.set_title('ELBO for DVAE')
ax1.legend(loc='lower right')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('ELBO')

ax2.plot(train_mse, marker='o', linestyle='solid',linewidth=1, markersize=3)
#ax2.plot(valid_mse, label='Validation set', marker='o', linestyle='solid',linewidth=1, markersize=3)
ax2.axvline(x = best_epoch, color='r', linestyle = '--')
ax2.set_ylim(2e-4, 2e-3)
ax2.set_title("MSE for the missing NIRS reconstruction in training set of DVAE")
ax2.legend(loc='upper right')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('MSE')
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0, 0.5, 'MSE')

# %%
# Training MLVAE
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)
torch.cuda.manual_seed(seed)
train_loss, train_loss_dict, train_mse, best_epoch = mlvae_trainer.train(nb_epochs=300,device=device,print_rate=100,model_save_path='saved_models/mlvae_raw_60.pth')
# Out:
# Epoch [1/300]:
# Reconstruction:
# Train: ELBO: -1.0639, Reconstruction term: -1.0452, KLD_v term: 0.1215, KLD_e term: 0.0660.
# Predict missing NIRS:
# Train set: MSE: 0.1775779
# min MSE: 0.17757786703268244.
# Epoch [100/300]:
# Reconstruction:
# Train: ELBO: 2.4604, Reconstruction term: 2.5020, KLD_v term: 0.3624, KLD_e term: 0.0537.
# Predict missing NIRS:
# Train set: MSE: 0.0015440
# min MSE: 0.0014313886308197508.
# Epoch [200/300]:
# Reconstruction:
# Train: ELBO: 2.6950, Reconstruction term: 2.7594, KLD_v term: 0.4378, KLD_e term: 0.2058.
# Predict missing NIRS:
# Train set: MSE: 0.0007500
# min MSE: 0.0007500488562816749.
# Epoch [300/300]:
# Reconstruction:
# Train: ELBO: 2.6184, Reconstruction term: 2.6872, KLD_v term: 0.4403, KLD_e term: 0.2471.
# Predict missing NIRS:
# Train set: MSE: 0.0007804
# min MSE: 0.0006165357771189675.

# %%
# PLot training ELBO curve and MSE loss in prediction missing NIRS
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(18,8))
ax1.plot(train_loss, label='Training set', marker='o', linestyle='solid', linewidth=1, markersize=3)
#ax1.plot(valid_loss, label='Validation set', marker='o', linestyle='solid', linewidth=1, markersize=3)
ax1.axvline(x = best_epoch, color='r', linestyle = '--')
ax1.set_title('ELBO for MLVAE')
ax1.legend(loc='lower right')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('ELBO')

ax2.plot(train_mse, marker='o', linestyle='solid',linewidth=1, markersize=3)
#ax2.plot(valid_mse, label='Validation set', marker='o', linestyle='solid',linewidth=1, markersize=3)
ax2.axvline(x = best_epoch, color='r', linestyle = '--')
ax2.set_ylim(2e-4, 2e-3)
ax2.set_title("MSE for the missing NIRS reconstruction in training set of MLVAE")
ax2.legend(loc='upper right')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('MSE')
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0, 0.5, 'MSE')

# %%
# Training HVAE
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)
torch.cuda.manual_seed(seed)
train_loss, train_loss_dict, train_mse, best_epoch = hvae_trainer.train(nb_epochs=300,device=device,print_rate=50,model_save_path='saved_models/hvae_raw_20.pth')
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-16-56faa91eaebe> in <cell line: 6>()
#       4 random.seed(seed)
#       5 torch.cuda.manual_seed(seed)
# ----> 6 train_loss, train_loss_dict, train_mse, best_epoch = hvae_trainer.train(nb_epochs=300,device=device,print_rate=50,model_save_path='saved_models/hvae_raw_20.pth')
#
# /content/drive/MyDrive/dothanhdatle_new/training/trainer.py in train(self, nb_epochs, device, print_rate, lr_decay, step_size, factor, model_save_path)
#      24         train_loader = self.data_loader.load_train(self.train_miss,self.model_type)
#      25         loss_train, train_loss_dict, \
# ---> 26             mse_train, best_epoch = self.model.train_(train_loader, train_data=self.train_miss, train_gt=self.train_gt,
#      27                                                       optimizer=self.optimizer, nb_epochs=nb_epochs,
#      28                                                       device=device, print_rate = print_rate,
#
# /content/drive/MyDrive/dothanhdatle_new/models/HVAE.py in train_(self, train_loader, train_data, train_gt, optimizer, nb_epochs, device, print_rate, lr_decay, step_size, factor, model_save_path)
#     332             # Training
#     333             train_loss, loss_dict_new, rec_term_train, kld_v_train, kld_e_train, kld_ve_train, kld_ev_train = \
# --> 334                 self.train_one_epoch(train_loader, nb_epochs, epoch, optimizer, device)
#     335             loss_train.append(train_loss/len(train_loader))
#     336             train_loss_dict = append_elbo_dict(train_loss_dict, loss_dict_new)
#
# /content/drive/MyDrive/dothanhdatle_new/models/HVAE.py in train_one_epoch(self, train_loader, nb_epochs, epoch, optimizer, device)
#     286             envs = envs
#     287
# --> 288             loss, loss_dict = self.step(x, nb_epochs, epoch, vars, envs,
#     289                                         train_loader, device, optimizer,train=True)
#     290             train_loss += loss.item()
#
# /content/drive/MyDrive/dothanhdatle_new/models/HVAE.py in step(self, x, nb_epochs, epoch, vars, envs, dataloader, device, optimizer, train)
#     267             optimizer.zero_grad()
#     268
# --> 269         rec_term, kld_v, kld_e, kld_ve, kld_ev = self.forward(x, vars, envs, dataloader, device, train=train)
#     270
#     271         loss, loss_dict = self.loss_function(nb_epochs, epoch, rec_term, kld_v, kld_e, kld_ve, kld_ev, train = train)
#
# /content/drive/MyDrive/dothanhdatle_new/models/HVAE.py in forward(self, x, vars, envs, dataloader, device, train)
#     208         # Compute reconstruction term
#     209         z = torch.cat((z_ve, z_ev), dim = -1)
# --> 210         self.pxz_distribution.param = self.decode(z)
#     211         rec_term += torch.mean(self.pxz_distribution.llkh(x))
#     212
#
# /content/drive/MyDrive/dothanhdatle_new/models/HVAE.py in decode(self, z)
#     123         """
#     124         z = z.reshape(1,-1)
# --> 125         output = self.dec_mlp(z)
#     126         output = output.view(z.shape[0],-1, self.hidden_dims[::-1][-1])
#     127         output = self.dec_linear(output)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     217     def forward(self, input):
#     218         for module in self:
# --> 219             input = module(input)
#     220         return input
#     221
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     217     def forward(self, input):
#     218         for module in self:
# --> 219             input = module(input)
#     220         return input
#     221
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# /content/drive/MyDrive/dothanhdatle_new/models/HVAE.py in forward(self, x)
#      22
#      23     def forward(self, x):
# ---> 24         return self.linear_layer(x)
#      25
#      26 class HVAE(nn.Module):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     115
#     116     def forward(self, input: Tensor) -> Tensor:
# --> 117         return F.linear(input, self.weight, self.bias)
#     118
#     119     def extra_repr(self) -> str:
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (1x7680 and 128x256)

# %%
# PLot training ELBO curve and MSE loss in prediction missing NIRS
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(18,8))
ax1.plot(train_loss, label='Training set', marker='o', linestyle='solid', linewidth=1, markersize=3)
#ax1.plot(valid_loss, label='Validation set', marker='o', linestyle='solid', linewidth=1, markersize=3)
ax1.axvline(x = best_epoch, color='r', linestyle = '--')
ax1.set_title('ELBO for HVAE')
ax1.legend(loc='lower right')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('ELBO')

ax2.plot(train_mse, marker='o', linestyle='solid',linewidth=1, markersize=3)
#ax2.plot(valid_mse, label='Validation set', marker='o', linestyle='solid',linewidth=1, markersize=3)
ax2.axvline(x = best_epoch, color='r', linestyle = '--')
ax2.set_ylim(2e-4, 2e-3)
ax2.set_title("MSE for the missing NIRS reconstruction in training set of HVAE")
ax2.legend(loc='upper right')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('MSE')
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0, 0.5, 'MSE')

# %%
# Training HVAE
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)
torch.cuda.manual_seed(seed)
train_loss, train_loss_dict, train_mse, best_epoch = hvae_trainer.train(nb_epochs=200,device=device,print_rate=50,model_save_path='saved_models/hvae_raw_20_1.pth')
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch [1/200]:
# Reconstruction:
# Train: ELBO: -30.2604, Reconstruction term: -5.9158, KLD_v: 3.1311, KLD_e : 4.1895. KLD_ve : 6.1581. KLD_ev : 10.8658.
# Predict missing NIRS:
# Train set: MSE: 2.3617613
# min MSE: 2.36176126882992.
#  24%|██▍       | 49/200 [04:08<12:01,  4.78s/it]
# Epoch [50/200]:
# Reconstruction:
# Train: ELBO: -4.0786, Reconstruction term: 0.4902, KLD_v: 1.1825, KLD_e : 3.1868. KLD_ve : 0.1775. KLD_ev : 0.0219.
#  25%|██▌       | 50/200 [04:13<12:05,  4.84s/it]
# Predict missing NIRS:
# Train set: MSE: 0.0220018
# min MSE: 0.021823604405820117.
#  50%|████▉     | 99/200 [08:22<07:58,  4.74s/it]
# Epoch [100/200]:
# Reconstruction:
# Train: ELBO: -1.8984, Reconstruction term: 2.1680, KLD_v: 0.9606, KLD_e : 2.9140. KLD_ve : 0.1703. KLD_ev : 0.0215.
#  50%|█████     | 100/200 [08:27<08:25,  5.06s/it]
# Predict missing NIRS:
# Train set: MSE: 0.0021443
# min MSE: 0.0021442883738657494.
#  74%|███████▍  | 149/200 [12:25<03:59,  4.70s/it]
# Epoch [150/200]:
# Reconstruction:
# Train: ELBO: -1.3389, Reconstruction term: 2.4125, KLD_v: 0.8306, KLD_e : 2.7368. KLD_ve : 0.1654. KLD_ev : 0.0186.
#  75%|███████▌  | 150/200 [12:29<03:48,  4.57s/it]
# Predict missing NIRS:
# Train set: MSE: 0.0013112
# min MSE: 0.0011673941245102608.
# 100%|█████████▉| 199/200 [16:18<00:04,  4.67s/it]
# Epoch [200/200]:
# Reconstruction:
# Train: ELBO: -1.0917, Reconstruction term: 2.4349, KLD_v: 0.7430, KLD_e : 2.6035. KLD_ve : 0.1611. KLD_ev : 0.0191.
# 100%|██████████| 200/200 [16:23<00:00,  4.92s/it]
# Predict missing NIRS:
# Train set: MSE: 0.0015549
# min MSE: 0.0010407301279195217.

# %%
# PLot training ELBO curve and MSE loss in prediction missing NIRS
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(18,8))
ax1.plot(train_loss, label='Training set', marker='o', linestyle='solid', linewidth=1, markersize=3)
#ax1.plot(valid_loss, label='Validation set', marker='o', linestyle='solid', linewidth=1, markersize=3)
ax1.axvline(x = best_epoch, color='r', linestyle = '--')
ax1.set_title('ELBO for HVAE')
ax1.legend(loc='lower right')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('ELBO')

ax2.plot(train_mse, marker='o', linestyle='solid',linewidth=1, markersize=3)
#ax2.plot(valid_mse, label='Validation set', marker='o', linestyle='solid',linewidth=1, markersize=3)
ax2.axvline(x = best_epoch, color='r', linestyle = '--')
ax2.set_ylim(2e-4, 2e-3)
ax2.set_title("MSE for the missing NIRS reconstruction in training set of HVAE")
ax2.legend(loc='upper right')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('MSE')
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0, 0.5, 'MSE')

# %% [markdown]
# **Load trained models**

# %%
# Load saved model
import os
state_dict = torch.load(os.path.join("saved_models", f"cvae_raw_60.pth"), weights_only=True,
            map_location=device)
cvae.load_state_dict(state_dict)

state_dict = torch.load(os.path.join("saved_models", f"dvae_raw_60.pth"), weights_only=True,
            map_location=device)
dvae.load_state_dict(state_dict)

state_dict = torch.load(os.path.join("saved_models", f"mlvae_raw_60.pth"), weights_only=True,
            map_location=device)
mlvae.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %% [markdown]
# **Reconstruction results**

# %%
# Reconstruct missing NIRS
cvae_recon = reconstruct_all_cvae(cvae, cvae_trainer.train_loader, train_miss_60, device)
dvae_recon = reconstruct_all_dvae(dvae, train_miss_60, device)
mlvae_recon = reconstruct_all_mlvae(mlvae, train_miss_60, device)

# %%
# Compute MSE for training set
print(f'MSE baseline prediction for training set: {mse_base_train}')

mse_cvae, mse_df_cvae = mse_miss_recon(cvae_recon, cvae_trainer.train_gt)
print('CVAE MSE for training set: ',mse_cvae)

mse_dvae, mse_df_dvae = mse_miss_recon(dvae_recon, dvae_trainer.train_gt)
print('DVAE MSE for training set: ',mse_dvae)

mse_mlvae, mse_df_mlvae = mse_miss_recon(mlvae_recon, mlvae_trainer.train_gt)
print('MLVAE MSE for training set: ',mse_mlvae)
# Out:
# MSE baseline prediction for training set: 0.0006063429044374437
# No NIRS groundtruth available for the Geno76 in the environment Ragt_2022
# No NIRS groundtruth available for the Geno84 in the environment Ragt_2021
# CVAE MSE for training set:  0.0005857337573174899
# No NIRS groundtruth available for the Geno76 in the environment Ragt_2022
# No NIRS groundtruth available for the Geno84 in the environment Ragt_2021
# DVAE MSE for training set:  0.0004832999969081867
# No NIRS groundtruth available for the Geno76 in the environment Ragt_2022
# No NIRS groundtruth available for the Geno84 in the environment Ragt_2021
# MLVAE MSE for training set:  0.0006165357771189674

# %%
# MSE for each environment with baseline prediction
mse_env_base_train = mse_base_train_df.groupby('Environnement')['MSE'].mean()

# MSE for each environment
mse_env_cvae = mse_df_cvae.groupby('Environnement')['MSE'].mean()
mse_env_dvae = mse_df_dvae.groupby('Environnement')['MSE'].mean()
mse_env_mlvae = mse_df_mlvae.groupby('Environnement')['MSE'].mean()

# %%
# Combine into a single DataFrame
df = pd.DataFrame({
    'Baseline': mse_env_base_train,
    'CVAE': mse_env_cvae,
    'DVAE': mse_env_dvae,
    'MLVAE': mse_env_mlvae
})

# Define the positions and width for the bars
positions = np.arange(len(df))
bar_width = 0.1

# Create the bar plots
fig, ax = plt.subplots(figsize=(12, 6))

bars1 = ax.bar(positions - bar_width, df['Baseline'], bar_width, label='Baseline')
bars2 = ax.bar(positions, df['CVAE'], bar_width, label='CVAE')
bars1 = ax.bar(positions + bar_width, df['DVAE'], bar_width, label='DVAE')
bars2 = ax.bar(positions + 2*bar_width, df['MLVAE'], bar_width, label='MLVAE')

# Add labels, title, and custom x-axis tick labels
ax.set_xlabel('Environment')
ax.set_ylabel('MSE')
ax.set_title('MSE of models on missing 60% training set')
ax.set_xticks(positions)
ax.set_xticklabels(df.index, rotation=45)
ax.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Compute MSE for test set
print(f'MSE baseline prediction for test set: {mse_base_test}')

mse_dvae, mse_df_dvae = dvae_trainer.test(device)
print('DVAE MSE for test set: ',mse_dvae)

mse_mlvae, mse_df_mlvae = mlvae_trainer.test(device)
print('MLVAE MSE for test set: ',mse_mlvae)
# Out:
# MSE baseline prediction for test set: 0.0010065292140328235
# No NIRS groundtruth available for the Geno187 in the environment Ragt_2022
# No NIRS groundtruth available for the Geno265 in the environment Ragt_2022
# DVAE MSE for test set:  0.000765579177068977
# No NIRS groundtruth available for the Geno187 in the environment Ragt_2022
# No NIRS groundtruth available for the Geno265 in the environment Ragt_2022
# MLVAE MSE for test set:  0.0008318977738251819

# %%
# MSE for each environment with baseline prediction
mse_env_base_test = mse_base_test_df.groupby('Environnement')['MSE'].mean()

# MSE for each environment
mse_env_dvae = mse_df_dvae.groupby('Environnement')['MSE'].mean()
mse_env_mlvae = mse_df_mlvae.groupby('Environnement')['MSE'].mean()

# %%
# Combine into a single DataFrame
df = pd.DataFrame({
    'Baseline': mse_env_base_test,
    'DVAE': mse_env_dvae,
    'MLVAE': mse_env_mlvae
})

# Define the positions and width for the bars
positions = np.arange(len(df))
bar_width = 0.1

# Create the bar plots
fig, ax = plt.subplots(figsize=(12, 6))

bars1 = ax.bar(positions - bar_width, df['Baseline'], bar_width, label='Baseline')
bars1 = ax.bar(positions , df['DVAE'], bar_width, label='DVAE')
bars2 = ax.bar(positions + bar_width, df['MLVAE'], bar_width, label='MLVAE')

# Add labels, title, and custom x-axis tick labels
ax.set_xlabel('Environment')
ax.set_ylabel('MSE')
ax.set_title('MSE of models on missing 20% test set')
ax.set_xticks(positions)
ax.set_xticklabels(df.index, rotation=45)
ax.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Latent space

# %% [markdown]
# **Latent space visualisation**

# %%
z_cvae, geno, env = latent_cvae(cvae, cvae_trainer.train_loader.dataset, device)
z_cvae_reduce = dimension_reduce(z_cvae, type='pca')
plt.figure()
sns.scatterplot(x = z_cvae_reduce[:,0], y = z_cvae_reduce[:,1], hue = env)
plt.title('Latent space visualization by environments for CVAE')
# Out:
# Text(0.5, 1.0, 'Latent space visualization by environments for CVAE')

# %%
# Choose randomly 5 varieties to visualize
random_geno = np.random.choice(geno, 5, replace=False)

# %%
random_geno = ['Geno268','Geno122','Geno85','Geno3','Geno162']

# %%
all_indices = []
for i in random_geno:
    indices = np.where(geno == i)[0]
    all_indices = np.concatenate((all_indices, indices))
all_indices = all_indices.astype(int)
z_geno = z_cvae_reduce[all_indices]
geno_list = geno[all_indices]
plt.figure()
sns.scatterplot(x = z_geno[:,0], y = z_geno[:,1], hue = geno_list)
plt.title('Latent space visualization by 5 varieties for CVAE')
# Out:
# Text(0.5, 1.0, 'Latent space visualization by 5 varieties for CVAE')

# %%
z_dvae, geno, env = latent_dvae(dvae, dvae_trainer.train_loader.dataset, device)
z_dvae_reduce = dimension_reduce(z_dvae, type='pca')
plt.figure()
sns.scatterplot(x = z_dvae_reduce[:,0], y = z_dvae_reduce[:,1], hue = env)
plt.title('Latent space visualization by environments for DVAE')
# Out:
# Text(0.5, 1.0, 'Latent space visualization by environments for DVAE')

# %%
all_indices = []
for i in random_geno:
    indices = np.where(geno == i)[0]
    all_indices = np.concatenate((all_indices, indices))
all_indices = all_indices.astype(int)
z_geno = z_dvae_reduce[all_indices]
geno_list = geno[all_indices]
plt.figure()
sns.scatterplot(x = z_geno[:,0], y = z_geno[:,1], hue = geno_list)
plt.title('Latent space visualization by 5 varieties for DVAE')
# Out:
# Text(0.5, 1.0, 'Latent space visualization by 5 varieties for DVAE')

# %%
z_mlvae, geno, env = latent_mlvae(mlvae, mlvae_trainer.train_loader.dataset, device)
z_mlvae_reduce = dimension_reduce(z_mlvae, type='pca')
plt.figure()
sns.scatterplot(x = z_mlvae_reduce[:,0], y = z_mlvae_reduce[:,1], hue = env)
plt.title('Latent space visualization by environments for MLVAE')
# Out:
# Text(0.5, 1.0, 'Latent space visualization by environments for MLVAE')

# %%
all_indices = []
for i in random_geno:
    indices = np.where(geno == i)[0]
    all_indices = np.concatenate((all_indices, indices))
all_indices = all_indices.astype(int)
z_geno = z_mlvae_reduce[all_indices]
geno_list = geno[all_indices]
plt.figure()
sns.scatterplot(x = z_geno[:,0], y = z_geno[:,1], hue = geno_list)
plt.title('Latent space visualization by 5 varieties for MLVAE')
# Out:
# Text(0.5, 1.0, 'Latent space visualization by 5 varieties for MLVAE')
